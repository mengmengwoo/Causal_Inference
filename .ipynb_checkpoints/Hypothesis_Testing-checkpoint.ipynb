# %% [markdown]
# Data: Open University Learning Analytics Dataset (OULAD)
#
# https://www.kaggle.com/datasets/anlgrbz/student-demographics-online-education-dataoulad/data?select=studentAssessment.csv

# %%
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ## Read in Data

# %%
courses = pd.read_csv('Data/courses.csv')
assessments = pd.read_csv('Data/assessments.csv')
stu_assess = pd.read_csv('Data/studentAssessment.csv')
regist = pd.read_csv('Data/studentRegistration.csv')
vle = pd.read_csv('Data/vle.csv')

print(courses.head())
print(assessments.head())
print(stu_assess.head())
print(regist.head())
print(vle.head())
# Out:
#   code_module code_presentation  module_presentation_length
# 0         AAA             2013J                         268
# 1         AAA             2014J                         269
# 2         BBB             2013J                         268
# 3         BBB             2014J                         262
# 4         BBB             2013B                         240
#   code_module code_presentation  id_assessment assessment_type   date  weight
# 0         AAA             2013J           1752             TMA   19.0    10.0
# 1         AAA             2013J           1753             TMA   54.0    20.0
# 2         AAA             2013J           1754             TMA  117.0    20.0
# 3         AAA             2013J           1755             TMA  166.0    20.0
# 4         AAA             2013J           1756             TMA  215.0    30.0
#    id_assessment  id_student  date_submitted  is_banked  score
# 0           1752       11391              18          0   78.0
# 1           1752       28400              22          0   70.0
# 2           1752       31604              17          0   72.0
# 3           1752       32885              26          0   69.0
# 4           1752       38053              19          0   79.0
#   code_module code_presentation  id_student  date_registration  \
# 0         AAA             2013J       11391             -159.0
# 1         AAA             2013J       28400              -53.0
# 2         AAA             2013J       30268              -92.0
# 3         AAA             2013J       31604              -52.0
# 4         AAA             2013J       32885             -176.0
#
#    date_unregistration
# 0                  NaN
# 1                  NaN
# 2                 12.0
# 3                  NaN
# 4                  NaN
#    id_site code_module code_presentation activity_type  week_from  week_to
# 0   546943         AAA             2013J      resource        NaN      NaN
# 1   546712         AAA             2013J     oucontent        NaN      NaN
# 2   546998         AAA             2013J      resource        NaN      NaN
# 3   546888         AAA             2013J           url        NaN      NaN
# 4   547035         AAA             2013J      resource        NaN      NaN

# %% [markdown]
# # Step 1: Data Exploration

# %% [markdown]
# ## 1.1. Analyze the Resource Type for Each Class

# %% [markdown]
# Only include the course that have one activity type throughout the course by keeping rows where the week_from and week_to columns are both missing.

# %%
vle_cleaned = vle[(vle['week_from'].isnull()) & (vle['week_to'].isnull())]
#  Class-year-activity level
vle_cleaned_group_act = vle_cleaned.groupby(['code_module', 'code_presentation','activity_type']).size().reset_index(name = 'cnt_act_type')
# Class-year level
vle_cleaned_group = vle_cleaned_group_act.groupby(['code_module', 'code_presentation']).agg(
    tot_cnt = ('cnt_act_type', 'sum'),
    most_freq_act = ('cnt_act_type', 'max')
).reset_index()
vle_comb = vle_cleaned_group_act.merge(vle_cleaned_group, on = ['code_module', 'code_presentation'])
# calculate the percentage of each activity amoung each class
vle_comb['act_percent'] = round((vle_comb['cnt_act_type']*100 / vle_comb['tot_cnt']), 2)
print(vle_comb.describe())
# Out:
#        cnt_act_type     tot_cnt  most_freq_act  act_percent
# count    229.000000  229.000000     229.000000   229.000000
# mean      22.895197  245.344978     115.489083     9.607336
# std       42.720095  125.644824      59.346116    15.654614
# min        1.000000   83.000000      32.000000     0.210000
# 25%        2.000000  173.000000      77.000000     0.980000
# 50%        6.000000  218.000000      95.000000     2.850000
# 75%       19.000000  315.000000     182.000000     8.650000
# max      236.000000  483.000000     236.000000    81.280000

# %% [markdown]
# Find the most frequently used activity type for each class

# %%
# find the most frequently used activity type for each class
most_freq_act = vle_comb[vle_comb['cnt_act_type'] == vle_comb['most_freq_act']]
print(most_freq_act)
# Out:
#     code_module code_presentation activity_type  cnt_act_type  tot_cnt  \
# 6           AAA             2013J      resource            95      208
# 15          AAA             2014J      resource            93      199
# 24          BBB             2013B      resource           236      315
# 34          BBB             2013J      resource           196      245
# 44          BBB             2014B      resource           191      235
# 55          BBB             2014J      resource            96      173
# 64          CCC             2014B      resource            78      191
# 73          CCC             2014J      resource            85      218
# 84          DDD             2013B      resource           182      428
# 95          DDD             2013J       subpage           194      462
# 105         DDD             2014B       subpage           193      452
# 114         DDD             2014J      resource           169      364
# 125         EEE             2013J      resource            34       86
# 136         EEE             2014B      resource            32       83
# 147         EEE             2014J      resource            37       88
# 161         FFF             2013B      resource           127      483
# 175         FFF             2013J      resource           120      246
# 189         FFF             2014B      resource            94      219
# 205         FFF             2014J      resource            65      193
# 213         GGG             2013J      resource            91      133
# 220         GGG             2014B      resource            77      120
# 227         GGG             2014J      resource            59      102
#
#      most_freq_act  act_percent
# 6               95        45.67
# 15              93        46.73
# 24             236        74.92
# 34             196        80.00
# 44             191        81.28
# 55              96        55.49
# 64              78        40.84
# 73              85        38.99
# 84             182        42.52
# 95             194        41.99
# 105            193        42.70
# 114            169        46.43
# 125             34        39.53
# 136             32        38.55
# 147             37        42.05
# 161            127        26.29
# 175            120        48.78
# 189             94        42.92
# 205             65        33.68
# 213             91        68.42
# 220             77        64.17
# 227             59        57.84

# %% [markdown]
# **Conclusion of the analysis**: Most of the materials among different classes are classified as 'resource', which consist of 33%-81% of all the available activities for each class.

# %% [markdown]
# ## 1.2. Analyze the Student

# %% [markdown]
# Only include the students that did not drop out

# %%
undrop_stu = regist[regist['date_unregistration'].isnull()]
all_crs_stu = undrop_stu.merge(courses, how = 'left', on = ['code_module','code_presentation'])

# %% [markdown]
# Find the assessment of each of the classes that each student took

# %%
course_assess= all_crs_stu.merge(assessments, how = 'left', on = ['code_module','code_presentation'])
stu_course_score = course_assess.merge(stu_assess, how = 'left', on = ['id_assessment', 'id_student'])

# %% [markdown]
# Find the final score at the course-student level

# %%
stu_course_score = stu_course_score.drop(['date_unregistration'], axis = 1)
stu_course_score = stu_course_score.dropna()

# %% [markdown]
# Make sure the assessment_type only consist of TMA, CMA and Exam

# %%
stu_course_score[['assessment_type']].drop_duplicates()
# Out:
#       assessment_type
# 0                 TMA
# 3732              CMA
# 85677            Exam

# %% [markdown]
# Separate the Final Exam, TMA and CMA

# %%
# Final
final_exam = stu_course_score[stu_course_score['assessment_type'] =='Exam']

# TMA
tma = stu_course_score[stu_course_score['assessment_type'] =='TMA']

# CMA
cma = stu_course_score[stu_course_score['assessment_type'] =='CMA']

# %%
print('Tutor Marked Assessment (TMA)')
print(tma.describe())

print('\n\nComputer Marked Assessment (CMA)')
print(cma.describe())
# Out:
# Tutor Marked Assessment (TMA)
#          id_student  date_registration  module_presentation_length  \
# count  8.953600e+04       89536.000000                89536.000000
# mean   7.095677e+05         -66.699015                  256.048584
# std    5.586499e+05          46.909243                   13.121811
# min    6.516000e+03        -310.000000                  234.000000
# 25%    5.045960e+05         -95.000000                  241.000000
# 50%    5.872970e+05         -53.000000                  262.000000
# 75%    6.424442e+05         -29.000000                  268.000000
# max    2.698588e+06         124.000000                  269.000000
#
#        id_assessment          date        weight  date_submitted  \
# count   89536.000000  89536.000000  89536.000000    89536.000000
# mean    25164.538041     98.571245     16.903335       97.341706
# std      9081.128121     59.760061      8.344443       61.125869
# min      1752.000000     12.000000      0.000000      -11.000000
# 25%     15020.000000     47.000000     12.500000       45.000000
# 50%     25355.000000     96.000000     18.000000       95.000000
# 75%     34873.000000    152.000000     25.000000      151.000000
# max     37437.000000    215.000000     35.000000      240.000000
#
#           is_banked         score
# count  89536.000000  89536.000000
# mean       0.011336     73.362502
# std        0.105867     17.848616
# min        0.000000      0.000000
# 25%        0.000000     64.000000
# 50%        0.000000     76.000000
# 75%        0.000000     86.000000
# max        1.000000    100.000000
#
#
# Computer Marked Assessment (CMA)
#          id_student  date_registration  module_presentation_length  \
# count  6.626200e+04       66262.000000                66262.000000
# mean   6.968227e+05         -63.782409                  254.260617
# std    5.389633e+05          46.249298                   14.254697
# min    2.362900e+04        -310.000000                  234.000000
# 25%    5.067530e+05         -90.000000                  240.000000
# 50%    5.825200e+05         -52.000000                  261.000000
# 75%    6.316810e+05         -28.000000                  268.000000
# max    2.698125e+06         124.000000                  269.000000
#
#        id_assessment          date        weight  date_submitted  \
# count   66262.000000  66262.000000  66262.000000    66262.000000
# mean    28759.168000    181.646434      1.210452      143.016767
# std      8574.313504     70.452732      2.233242       69.262633
# min     14991.000000     18.000000      0.000000       -8.000000
# 25%     24287.000000    131.000000      0.000000       84.000000
# 50%     34870.000000    222.000000      0.000000      153.000000
# 75%     34905.000000    236.000000      1.000000      209.000000
# max     37443.000000    241.000000      8.000000      245.000000
#
#           is_banked         score
# count  66262.000000  66262.000000
# mean       0.007003     81.756708
# std        0.083388     17.011347
# min        0.000000      0.000000
# 25%        0.000000     73.000000
# 50%        0.000000     83.000000
# 75%        0.000000     98.000000
# max        1.000000    100.000000

# %% [markdown]
# **Conclusion of the analysis**:
# * There is more TMA than CMA
# * Looking at the mean and the percentile distribution (25th, 50th and 75th), students perform better at CMA type of quiz than TMA type of quiz.
#
# **Next Step**:
# I am interested in analyze if there is statistical difference that indicate students receive higher score for CMA type of quiz than TMA type of quiz.

# %% [markdown]
# # Step 2: Hypothesis Testinig

# %% [markdown]
# ## 2.1. Normality Test

# %% [markdown]
# ### 2.1.1  Individual CMA and TMA Data

# %% [markdown]
# Prior to performing the T-test. It is essential to see if the data is approximately normally distributed. Thus, I analyze both the CMA scores and the TMA scores using histograms and Q-Q plots.

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# TMA
sns.histplot(tma['score'], kde=True, ax=axes[0, 0], color='skyblue')
axes[0, 0].set_title("Histogram: TMA Scores")

stats.probplot(tma['score'], dist="norm", plot=axes[1, 0])
axes[1, 0].set_title("Q-Q Plot: TMA Scores")

# CMA
sns.histplot(cma['score'], kde=True, ax=axes[0, 1], color='salmon')
axes[0, 1].set_title("Histogram: CMA Scores")

stats.probplot(cma['score'], dist="norm", plot=axes[1, 1])
axes[1, 1].set_title("Q-Q Plot: CMA Scores")


plt.tight_layout()
plt.show()

# %% [markdown]
# **Comment**:
# * From the Histograms, it seems that both the CMA and the TMA data are left skewed.
# * In addition, from the Q-Q plots, it seems that both the CMA and the TMA data are heavy in both ends of the tails.
#
# **Conclusion**:
# From the Histogram and the Q-Q plots, both the CMA and the TMA data failed the normality test.
#
# **Next Step**:
# I am going to try to see if taking the average of the score among each test will help the data to be more normally distributed for the Hypothesis Testing.

# %% [markdown]
# ### 2.1.2. Test Level of CMA and TMA Data

# %% [markdown]
# **Central Limit Theorem**:
#
# Since the CMA and the TMA data failed the normality test, I am going taking the mean of the score of each class for both the TMA and the CMA test. If the sample is large enough, we can use the Central Limit Theorem to ensure that the mean of the score will follow the normal distribution.
#
# By CLT, as the number of sample mean increase, the distribution of the sample mean will be approximately normal.
#
# <center>ie. $n \rightarrow\infty,\space\bar{x}\sim N\left(\mu, \frac{\sigma^2}{n}\right)$ </center>

# %%
# Take the mean of the CMA test and the mean of the TMA test 
tma_grp = tma.groupby(['id_assessment'])['score'].mean().reset_index(name = 'test_lvl_mean_score')
cma_grp = cma.groupby(['id_assessment'])['score'].mean().reset_index(name = 'test_lvl_mean_score')

n = len(tma_grp)
m = len(cma_grp)
print(n)
print(m)
# Out:
# 106
# 76

# %% [markdown]
# **Conclusion**: Since we have large amount of test-level mean score for both the TMA and CMA tests, by the CLT, the test-level mean score of the TMA and CMA tests are normally distributed. To further analyze the normality, the following looks into histograms and the Q-Q plots of the mean score data

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# TMA
sns.histplot(tma_grp['test_lvl_mean_score'], kde=True, ax=axes[0, 0], color='skyblue')
axes[0, 0].set_title("Histogram: Log of TMA Scores")

stats.probplot(tma_grp['test_lvl_mean_score'], dist="norm", plot=axes[1, 0])
axes[1, 0].set_title("Q-Q Plot: Log of TMA Scores")

# CMA
sns.histplot(cma_grp['test_lvl_mean_score'], kde=True, ax=axes[0, 1], color='salmon')
axes[0, 1].set_title("Histogram: CMA Scores")

stats.probplot(cma_grp['test_lvl_mean_score'], dist="norm", plot=axes[1, 1])
axes[1, 1].set_title("Q-Q Plot: CMA Scores")


plt.tight_layout()
plt.show()

# %% [markdown]
# **Comment**:
# * From the Histograms and the Q-Q plots, it seems that the test-level mean scores of both the CMA and the TMA data are normally distributed.
#
# **Conclusion**:
# From the Histogram and the Q-Q plots, both the CMA and the TMA data passed the normality test.
#
# **Next Step**:
# In addition to testing the normality of the test-level mean scores of both the CMA and the TMA data. We also need to analyze if the variance of both data are statistically equivalent.
# * If the variance are statistically equivalent: Pooled T-test will be used.
# * If the variance are not statistically equivalent: Welch's T-test will be used

# %%
# calculate the standard error
tma_grp_mean = tma_grp['test_lvl_mean_score'].mean()
tma_grp_std = tma_grp['test_lvl_mean_score'].std()
tma_grp_var = tma_grp['test_lvl_mean_score'].var()

cma_grp_mean = cma_grp['test_lvl_mean_score'].mean()
cma_grp_std = cma_grp['test_lvl_mean_score'].std()
cma_grp_var = cma_grp['test_lvl_mean_score'].var()

print(tma_grp_mean)
print(cma_grp_mean)
print(tma_grp_std)
print(cma_grp_std)
# Out:
# 73.0578526030691
# 81.6981860696359
# 5.487645965945215
# 6.767688835170332

# %% [markdown]
# ## 2.2. F-Test for Sigma
# Since the pooled T-test required the numerator follows $N(0,1)$ and the denominator follows the $\chi^2$ distribution, and that $\sigma_{TMA} = \sigma_{CMA} $, we are using the F-test to analyze if there is statistical significant difference between the variance of TMA and the variance of CMA with $\alpha = 0.05$
# <center>F Statistic: $\dfrac{\sigma^2_{TMA}}{\sigma^2_{CMA}}$</center>
# <center>$H_0: \sigma^2_{TMA} = \sigma^2_{CMA} $</center>
# <center>$H_1: \sigma^2_{TMA} \ne \sigma^2_{CMA} $</center>

# %%
f_stat = tma_grp_var / cma_grp_var
print('F Statistic:',f_stat)

f_p_val = (1- stats.f.cdf(f_stat, n-1, m-1))*2
print('P Value:', f_p_val)
# Out:
# F Statistic: 0.6574934117162795
# P Value: 1.952678691866805

# %% [markdown]
# **Conclusion**: With 95% confidence level, I failed to reject $H_0$ and concluded that $\sigma_{TMA} = \sigma_{CMA} $
#
# **Next Step**: Since the test-level mean of the TMA and the CMA quiz are both normally distributed (2.1), and that there is no significant difference between the variance of the TMA and the variance of the CMA, we can use pooled T-test to analyze if the test level mean of the TMA nad the CMA quiz are statistically significant.

# %% [markdown]
# ## 2.3. Pooled T-Test
#
# **Research Question**: Is there statistically significant difference between the mean of the TMA test and the mean of the CMA test with $\alpha = 0.05$?
#
# <center>$H_0: \mu_{TMA} = \mu_{CMA}$</center>
# <center>$H_1: \mu_{TMA} > \mu_{CMA}$</center>

# %% [markdown]
# <center>Pooled T Statistic: $\dfrac{(\bar{x}_{TMA} - \bar{x}_{CMA}) - (\mu_{TMA} -\mu_{CMA})}{\sqrt{S_p^2 (\dfrac{1}{n} + \dfrac{1}{m})}}$</center>
# <center>where $S_p^2 = \dfrac{(n-1)S_{TMA}^2 + (m-1)S_{CMA}^2}{n+m-2}$</center>
# <center>$n:$ TMA sample size</center>
# <center>$m:$ CMA sample size</center>

# %%
s_pooled = np.sqrt(((n-1) * tma_grp_var + (m-1)*cma_grp_var)/ (n+m-2))
print(f'Pooled Sample Standard Deviation:{s_pooled:.4f}')

t_stat = (tma_grp_mean-cma_grp_mean) / (s_pooled * np.sqrt((1/n) + (1/m)))
print(f'T statistic:{t_stat:.4f}')

p_value = stats.t.sf(np.abs(t_stat), n+m-2)
print(f'P value:{p_value:.4f}')
# Out:
# Pooled Sample Standard Deviation:6.0540
# T statistic:-9.4954
# P value:0.0000

# %%
t_stat, p_value = stats.ttest_ind(tma_grp['test_lvl_mean_score'], cma_grp['test_lvl_mean_score'], equal_var=True)

print(f"T-statistic: {t_stat:.4f}")
print(f"P-value: {p_value:.4f}")
# Out:
# T-statistic: -9.4954
# P-value: 0.0000

# %% [markdown]
# **Conclusion**: With 95% confidence level, I reject $H_0$ and concluded that the mean of the test level CMA tests are higher than the mean of the test level TMA tests.

# %%
df = pd.DataFrame({
    'Score': list(tma_grp['test_lvl_mean_score']) + list(cma_grp['test_lvl_mean_score']),
    'Assessment': ['TMA'] * len(tma_grp['test_lvl_mean_score']) + ['CMA'] * len(cma_grp['test_lvl_mean_score'])
})


sns.stripplot(x='Assessment', y='Score', data=df, hue='Assessment', jitter=True, size=8, alpha=0.6)


plt.axhline(y=tma_grp_mean, xmin=0.1, xmax=0.4, 
            color='blue', linestyle='--', label='TMA Mean')
plt.axhline(y=cma_grp_mean, xmin=0.6, xmax=0.9, 
            color='orange', linestyle='--', label='CMA Mean')

plt.title('Distribution of Class Means: TMA vs CMA')
plt.ylabel('Mean Score per Class')
plt.savefig('dot_plot_analysis.png')

# %% [markdown]
# ## 2.4. Confidence Intervals

# %%
alpha = 0.05

# %%
t_crit_tma = stats.t.ppf(1 - alpha/2, n-1)
tma_se = tma_grp_std/ np.sqrt(n)
tma_ci = [tma_grp_mean - t_crit_tma * tma_se , tma_grp_mean + t_crit_tma * tma_se]

t_crit_cma = stats.t.ppf(1-alpha/2, m-1)
cma_se = cma_grp_std/ np.sqrt(m)
cma_ci = [cma_grp_mean - t_crit_cma * cma_se, cma_grp_mean + t_crit_cma * cma_se]
# Out:
# 1.056855004417936
# 1.5464831464076745
# -6.03699531574118
# [np.float64(72.00099759865115), np.float64(74.11470760748703)]
# [np.float64(80.15170292322821), np.float64(83.24466921604358)]

# %%
y_pos = [0.4, 0.7] 
labels = ['TMA Group', 'CMA Group']
means = [tma_grp_mean, cma_grp_mean]
errors = [t_crit_tma * tma_se, t_crit_cma * cma_se]

plt.figure(figsize=(8, 4)) # Reduced height to match the closer bars

# 2. Use y_pos instead of labels in the errorbar function
plt.errorbar(means, y_pos, xerr=errors, fmt='o', color='black', 
             ecolor='firebrick', elinewidth=3, capsize=10)

# 3. Manually set the ticks so the labels still show up correctly
plt.yticks(y_pos, labels)

# 4. Adjust the Y-axis limits so they don't look "lost" in a giant empty space
plt.ylim(0, 1) 

plt.title('95% Confidence Intervals of the Mean', fontsize=14)
plt.xlabel('Score / Value')
plt.grid(axis='x', linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()
