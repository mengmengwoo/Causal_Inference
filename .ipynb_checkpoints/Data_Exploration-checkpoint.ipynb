# %% [markdown]
# Data: Open University Learning Analytics Dataset (OULAD)
#
# https://www.kaggle.com/datasets/anlgrbz/student-demographics-online-education-dataoulad/data?select=studentAssessment.csv

# %% [markdown]
# Research Question:
# Does having higher length of course interaction (from vle table) lead to higher score (student assessment)?

# %%
import pandas as pd

# %% [markdown]
# # Step 1: Merge and Clean Data

# %%
courses = pd.read_csv('Data/courses.csv')
assessments = pd.read_csv('Data/assessments.csv')
stu_assess = pd.read_csv('Data/studentAssessment.csv')
regist = pd.read_csv('Data/studentRegistration.csv')

print(courses.head())
print(assessments.head())
print(stu_assess.head())
print(regist.head())
# Out:
#   code_module code_presentation  module_presentation_length
# 0         AAA             2013J                         268
# 1         AAA             2014J                         269
# 2         BBB             2013J                         268
# 3         BBB             2014J                         262
# 4         BBB             2013B                         240
#   code_module code_presentation  id_assessment assessment_type   date  weight
# 0         AAA             2013J           1752             TMA   19.0    10.0
# 1         AAA             2013J           1753             TMA   54.0    20.0
# 2         AAA             2013J           1754             TMA  117.0    20.0
# 3         AAA             2013J           1755             TMA  166.0    20.0
# 4         AAA             2013J           1756             TMA  215.0    30.0
#    id_assessment  id_student  date_submitted  is_banked  score
# 0           1752       11391              18          0   78.0
# 1           1752       28400              22          0   70.0
# 2           1752       31604              17          0   72.0
# 3           1752       32885              26          0   69.0
# 4           1752       38053              19          0   79.0
#   code_module code_presentation  id_student  date_registration  \
# 0         AAA             2013J       11391             -159.0
# 1         AAA             2013J       28400              -53.0
# 2         AAA             2013J       30268              -92.0
# 3         AAA             2013J       31604              -52.0
# 4         AAA             2013J       32885             -176.0
#
#    date_unregistration
# 0                  NaN
# 1                  NaN
# 2                 12.0
# 3                  NaN
# 4                  NaN

# %%
print(assessments[(assessments['assessment_type'] == 'Exam') & (assessments['weight'] != 100)])
# Out:
# Empty DataFrame
# Columns: [code_module, code_presentation, id_assessment, assessment_type, date, weight]
# Index: []

# %% [markdown]
# Only include the students that did not drop out

# %%
undrop_stu = regist[regist['date_unregistration'].isnull()]

# %%
course_assess= courses.merge(assessments, on = ['code_module','code_presentation'])
stu_course_score = course_assess.merge(stu_assess, on = 'id_assessment')

# %% [markdown]
# Find the final score at the course-student level

# %%
stu_course_score['weighted_score'] = stu_course_score['score'] * stu_course_score['weight']*0.01

stu_course_lvl = stu_course_score.groupby(['id_student', 'code_module', 'code_presentation']).agg(
    final_score =('weighted_score', 'sum'),
    tot_weight = ('weight', 'sum')
).reset_index()
print(stu_course_lvl[stu_course_lvl['tot_weight']== 100])
print(stu_course_lvl[stu_course_lvl['tot_weight']!= 100])
print(stu_course_lvl[stu_course_lvl['tot_weight']== 200])
# Out:
#        id_student code_module code_presentation  final_score  tot_weight
# 0            6516         AAA             2014J        63.50       100.0
# 3           11391         AAA             2013J        82.40       100.0
# 6           23798         BBB             2013J        89.24       100.0
# 10          24734         AAA             2014J        47.50       100.0
# 11          25107         BBB             2013B        60.51       100.0
# ...           ...         ...               ...          ...         ...
# 25836     2698125         FFF             2013J        68.00       100.0
# 25838     2698257         AAA             2013J        69.40       100.0
# 25840     2698535         EEE             2013J        53.44       100.0
# 25841     2698577         BBB             2014J        55.80       100.0
# 25842     2698588         BBB             2014J        92.40       100.0
#
# [9126 rows x 5 columns]
#        id_student code_module code_presentation  final_score  tot_weight
# 1            8462         DDD             2013J       34.900        40.0
# 2            8462         DDD             2014J       43.000        50.0
# 4           23629         BBB             2013B       16.690        25.0
# 5           23698         CCC             2014J      149.970       200.0
# 7           24186         GGG             2014B        0.000         0.0
# ...           ...         ...               ...          ...         ...
# 25829     2695608         DDD             2013J      152.650       200.0
# 25830     2696376         DDD             2014B       24.425        70.0
# 25831     2697181         CCC             2014B      137.610       161.0
# 25837     2698251         DDD             2014B      102.675       200.0
# 25839     2698535         CCC             2014B        9.370        39.0
#
# [16717 rows x 5 columns]
#        id_student code_module code_presentation  final_score  tot_weight
# 5           23698         CCC             2014J      149.970       200.0
# 8           24213         DDD             2014B      136.400       200.0
# 22          27116         CCC             2014J      188.020       200.0
# 32          28046         DDD             2013J       89.900       200.0
# 43          29411         DDD             2013J      137.650       200.0
# ...           ...         ...               ...          ...         ...
# 25819     2693243         DDD             2013B      170.580       200.0
# 25825     2694886         DDD             2014B      138.875       200.0
# 25827     2694933         DDD             2013B      149.970       200.0
# 25829     2695608         DDD             2013J      152.650       200.0
# 25837     2698251         DDD             2014B      102.675       200.0
#
# [3507 rows x 5 columns]

# %%
print(stu_course_score[stu_course_score['is_banked']!= 0])
# Out:
#        code_module code_presentation  module_presentation_length  \
# 1641           AAA             2014J                         269
# 1685           AAA             2014J                         269
# 1690           AAA             2014J                         269
# 1693           AAA             2014J                         269
# 1708           AAA             2014J                         269
# ...            ...               ...                         ...
# 167452         GGG             2014J                         269
# 168095         GGG             2014J                         269
# 168106         GGG             2014J                         269
# 168848         GGG             2014J                         269
# 168858         GGG             2014J                         269
#
#         id_assessment assessment_type   date  weight  id_student  \
# 1641             1758             TMA   19.0    10.0      603861
# 1685             1758             TMA   19.0    10.0     1970390
# 1690             1758             TMA   19.0    10.0     2073016
# 1693             1758             TMA   19.0    10.0     2139353
# 1708             1758             TMA   19.0    10.0     2358969
# ...               ...             ...    ...     ...         ...
# 167452          37435             TMA   61.0     0.0      631446
# 168095          37436             TMA  124.0     0.0      624767
# 168106          37436             TMA  124.0     0.0      631446
# 168848          37437             TMA  173.0     0.0      624767
# 168858          37437             TMA  173.0     0.0      631446
#
#         date_submitted  is_banked  score  weighted_score
# 1641                -1          1   61.0             6.1
# 1685                -1          1   78.0             7.8
# 1690                -1          1   60.0             6.0
# 1693                -1          1   65.0             6.5
# 1708                -1          1   68.0             6.8
# ...                ...        ...    ...             ...
# 167452              -1          1   72.0             0.0
# 168095              -1          1   90.0             0.0
# 168106              -1          1   70.0             0.0
# 168848              -1          1   75.0             0.0
# 168858              -1          1   64.0             0.0
#
# [1909 rows x 12 columns]
